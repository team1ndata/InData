# %% [markdown]
# # Life Expectancy EUU EDA

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from empiricaldist import Pmf

# %% [markdown]
# ## Adolescent fertility rate - Region: Europe

# %%
adolescent_fertility_df = pd.read_csv('/work/Datasets/Adolescent fertility rate (births per 1,000 women ages 15-19)_table_EU', index_col='Unnamed: 0')
adolescent_fertility_df.head(30)
# Out:
#                                       indicator_value country_id  \
# 0   Adolescent fertility rate (births per 1,000 wo...         ES
# 1   Adolescent fertility rate (births per 1,000 wo...         ES
# 2   Adolescent fertility rate (births per 1,000 wo...         ES
# 3   Adolescent fertility rate (births per 1,000 wo...         ES
# 4   Adolescent fertility rate (births per 1,000 wo...         ES
# 5   Adolescent fertility rate (births per 1,000 wo...         ES
# 6   Adolescent fertility rate (births per 1,000 wo...         ES
# 7   Adolescent fertility rate (births per 1,000 wo...         ES
# 8   Adolescent fertility rate (births per 1,000 wo...         ES
# 9   Adolescent fertility rate (births per 1,000 wo...         ES
# 10  Adolescent fertility rate (births per 1,000 wo...         ES
# 11  Adolescent fertility rate (births per 1,000 wo...         ES
# 12  Adolescent fertility rate (births per 1,000 wo...         ES
# ...

# %%
adolescent_fertility_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310 entries, 0 to 309
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   indicator_value  310 non-null    object
#  1   country_id       310 non-null    object
#  2   country_value    310 non-null    object
#  3   countryiso3code  310 non-null    object
#  4   date             310 non-null    int64
#  5   value            305 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 17.0+ KB

# %% [markdown]
# Count the number of missing values in the column "value"

# %%
adolescent_fertility_df.value.isna().sum()
# Out:
# 5

# %%
for country in adolescent_fertility_df.country_value.unique():
    plt.plot(adolescent_fertility_df.date[adolescent_fertility_df.country_value == country], adolescent_fertility_df.value[adolescent_fertility_df.country_value == country], label=country)

plt.legend()
plt.show()

# %% [markdown]
# ## Birth rate - Region: Europe

# %% [markdown]
# ### Review
# This table presents how has the birth rate been through the years, for different countries along europe

# %%
birth_rate_df = pd.read_csv('/work/Datasets/Birth rate, crude (per 1,000 people)_table_EU', index_col='Unnamed: 0')
birth_rate_df.head()
# Out:
#                         indicator_value country_id country_value  \
# 0  Birth rate, crude (per 1,000 people)         ES         Spain
# 1  Birth rate, crude (per 1,000 people)         ES         Spain
# 2  Birth rate, crude (per 1,000 people)         ES         Spain
# 3  Birth rate, crude (per 1,000 people)         ES         Spain
# 4  Birth rate, crude (per 1,000 people)         ES         Spain
#
#   countryiso3code  date  value
# 0             ESP  2021    NaN
# 1             ESP  2020    7.1
# 2             ESP  2019    7.6
# 3             ESP  2018    7.9
# 4             ESP  2017    8.4

# %%
birth_rate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310 entries, 0 to 309
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   indicator_value  310 non-null    object
#  1   country_id       310 non-null    object
#  2   country_value    310 non-null    object
#  3   countryiso3code  310 non-null    object
#  4   date             310 non-null    int64
#  5   value            305 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 17.0+ KB

# %% [markdown]
# Count the number of missing values in the column "value"

# %%
birth_rate_df.value.isna().sum()
# Out:
# 5

# %%
for country in adolescent_fertility_df.country_value.unique():
    plt.plot(birth_rate_df.date[birth_rate_df.country_value == country], birth_rate_df.value[birth_rate_df.country_value == country], label=country)

plt.legend()
plt.show()

# %% [markdown]
# ## Life expectancy - Region: Europe

# %% [markdown]
# ### Review
#
# We can Apreciate Europe has been presenting a good increase on its life expectancy by almost 10 years in the last 30 years

# %%
life_expectancy_df = pd.read_csv('/work/Datasets/Life expectancy at birth, total (years)_table_EU', index_col='Unnamed: 0')
life_expectancy_df.head()
# Out:
#                            indicator_value country_id country_value  \
# 0  Life expectancy at birth, total (years)         ES         Spain
# 1  Life expectancy at birth, total (years)         ES         Spain
# 2  Life expectancy at birth, total (years)         ES         Spain
# 3  Life expectancy at birth, total (years)         ES         Spain
# 4  Life expectancy at birth, total (years)         ES         Spain
#
#   countryiso3code  date      value
# 0             ESP  2021        NaN
# 1             ESP  2020  82.334146
# 2             ESP  2019  83.831707
# 3             ESP  2018  83.431707
# 4             ESP  2017  83.282927

# %%
life_expectancy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310 entries, 0 to 309
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   indicator_value  310 non-null    object
#  1   country_id       310 non-null    object
#  2   country_value    310 non-null    object
#  3   countryiso3code  310 non-null    object
#  4   date             310 non-null    int64
#  5   value            305 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 17.0+ KB

# %%
life_expectancy_df.value.isna().sum()
# Out:
# 5

# %%
for country in adolescent_fertility_df.country_value.unique():
    plt.plot(life_expectancy_df.date[life_expectancy_df.country_value == country], life_expectancy_df.value[life_expectancy_df.country_value == country], label=country)

plt.legend()
plt.show()

# %% [markdown]
# ## Current Health Expenditure per Capita - Region: Europe

# %% [markdown]
# ### Review
#
# This tables shows the money each country has spend in health over the past years
#
# Empty values = 210

# %%
# Create the table dataframe 

health_expenditure_df = pd.read_csv('/work/Datasets/EUU/Current health expenditure per capita (current US$)_table_EU', index_col='Unnamed: 0')
health_expenditure_df.head()
# Out:
#                                      indicator_value country_id country_value  \
# 0  Current health expenditure per capita (current...         ES         Spain
# 1  Current health expenditure per capita (current...         ES         Spain
# 2  Current health expenditure per capita (current...         ES         Spain
# 3  Current health expenditure per capita (current...         ES         Spain
# 4  Current health expenditure per capita (current...         ES         Spain
#
#   countryiso3code  date        value
# 0             ESP  2021          NaN
# 1             ESP  2020          NaN
# 2             ESP  2019  2711.192871
# 3             ESP  2018  2740.269287
# 4             ESP  2017  2526.720459

# %%
# Get more information about the df
health_expenditure_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310 entries, 0 to 309
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   indicator_value  310 non-null    object
#  1   country_id       310 non-null    object
#  2   country_value    310 non-null    object
#  3   countryiso3code  310 non-null    object
#  4   date             310 non-null    int64
#  5   value            100 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 25.1+ KB

# %%
#locate how many empty values are in the column value
print(f'The total number of empty values is: {health_expenditure_df.value.isna().sum()}')

health_expenditure_df[health_expenditure_df.value.isna()].head(10)
# Out:
# The total number of empty values is: 210
#                                       indicator_value country_id  \
# 0   Current health expenditure per capita (current...         ES
# 1   Current health expenditure per capita (current...         ES
# 22  Current health expenditure per capita (current...         ES
# 23  Current health expenditure per capita (current...         ES
# 24  Current health expenditure per capita (current...         ES
# 25  Current health expenditure per capita (current...         ES
# 26  Current health expenditure per capita (current...         ES
# 27  Current health expenditure per capita (current...         ES
# 28  Current health expenditure per capita (current...         ES
# 29  Current health expenditure per capita (current...         ES
#
#    country_value countryiso3code  date  value
# 0          Spain             ESP  2021    NaN
# 1          Spain             ESP  2020    NaN
# 22         Spain             ESP  1999    NaN
# ...

# %%
# Lets graph to see how is the tendency through the years
for country in adolescent_fertility_df.country_value.unique():
    plt.plot(health_expenditure_df.date[health_expenditure_df.country_value == country], health_expenditure_df.value[health_expenditure_df.country_value == country], label=country)

plt.legend()
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=43b6c2e4-a275-4ea1-a380-ee09bbef7c51' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
